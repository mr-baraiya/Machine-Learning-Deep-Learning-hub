# %% [markdown]
# # **Week 5 – Deployment of Flask ML App on Render**
#
# This week, we prepare our Flask application for cloud deployment.
# We will generate required files (`requirements.txt`, `Procfile`), test the app locally, push to GitHub, and deploy the model as a live API on Render.
#
# ---

# %% [markdown]
# # Student Information
# **Name: Vishal Baraiya**
# **Enrollment No.: 23010101014**
# **Roll No.: C3-635**
# **Course:** Machine Learning & Deep Learning Project
#
# ---

# %% [markdown]
# # **Objectives**
# - Prepare Flask project structure for deployment
# - Create `requirements.txt` and `Procfile`
# - Test API locally
# - Push project to GitHub
# - Deploy ML Web App on Render
# - Test deployed API with JSON input

# %% [markdown]
# # **1. Project Folder Structure Required for Render**
#
# ```markdown
# Your final project folder should look like this:
#
# flask_app/
#  ├─ app.py
#  ├─ model_utils.py
#  ├─ templates/
#  │    ├─ index.html
#  │    └─ result.html
#  ├─ static/
# models/
#  ├─ logistic_weights.npy
#  ├─ logistic_bias.npy
#  └─ scaler.pkl
# requirements.txt
# Procfile
# README.md
